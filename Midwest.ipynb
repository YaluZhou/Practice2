# %% [markdown]
# # Analysis of Covid 19 spread in the Midwest states
# Team Name: "GIT YOUR POPCORN READY!"
#
# Team Members: Anu, Dipti, Korbin, Yalu
#
# Datasets used:
# 1. https://covidtracking.com/data
# 2. Census data
# 3. https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv

# %%
#Downloading and installing prerequisites
# !pip install census
# !pip install us
# Out:
# Requirement already satisfied: census in c:\users\aguha\anaconda3\lib\site-packages (0.8.13)
# Requirement already satisfied: requests>=1.1.0 in c:\users\aguha\anaconda3\lib\site-packages (from census) (2.22.0)
# Requirement already satisfied: future in c:\users\aguha\anaconda3\lib\site-packages (from census) (0.17.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aguha\anaconda3\lib\site-packages (from requests>=1.1.0->census) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\aguha\anaconda3\lib\site-packages (from requests>=1.1.0->census) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aguha\anaconda3\lib\site-packages (from requests>=1.1.0->census) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\aguha\anaconda3\lib\site-packages (from requests>=1.1.0->census) (3.0.4)
# Collecting us
#   Downloading https://files.pythonhosted.org/packages/ad/ca/79a014a51a739115cc894676aac6f86535c0882ba128132f9c468dff707c/us-2.0.1.tar.gz
# Collecting jellyfish==0.6.1 (from us)
#   Downloading https://files.pythonhosted.org/packages/61/3f/60ac86fb43dfbf976768e80674b5538e535f6eca5aa7806cf2fdfd63550f/jellyfish-0.6.1.tar.gz (132kB)
# Building wheels for collected packages: us, jellyfish
#   Building wheel for us (setup.py): started
#   Building wheel for us (setup.py): finished with status 'done'
#   Created wheel for us: filename=us-2.0.1-cp37-none-any.whl size=11858 sha256=b0c698f41f1adecd863bde1cc0ec2b38527ca31180c486cb82c711e5f5624331
#   Stored in directory: C:\Users\aguha\AppData\Local\pip\Cache\wheels\06\41\3e\a009ade7e7b88199f1a5ff29fac69a4dc332a8b05d50e038a9
#   Building wheel for jellyfish (setup.py): started
#   Building wheel for jellyfish (setup.py): finished with status 'done'
#   Created wheel for jellyfish: filename=jellyfish-0.6.1-cp37-none-any.whl size=10384 sha256=013ebae70a69707aa27f649dff418996224c8f9e1c899fb7f29849884fad3be8
#   Stored in directory: C:\Users\aguha\AppData\Local\pip\Cache\wheels\9c\6f\33\92bb9a4b4562a60ba6a80cedbab8907e48bc7a8b1f369ea0ae
# Successfully built us jellyfish
# Installing collected packages: jellyfish, us
# Successfully installed jellyfish-0.6.1 us-2.0.1

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from time import ctime as convert
from datetime import datetime
from census import Census
import gmaps

# Census & gmaps API Keys
from config import api_key
c = Census(api_key, year=2013)

# %% [markdown]
# # What factors associate with COVID-19 spread?
#
#
# Some racial groups are more vulnerable
#
# Is poverty also a factor?
#
# Instead of focusing on just Illinois, we decided to study all 12 states in midwest to expand the project scope.
#
# We can analyse multiple datasets to understand this much better.

# %%
# Read in the csv file for Covid Data and Create dataframe
covid_df = pd.read_csv('illinois_covid_data.csv')
covid_df=covid_df.drop([ "positiveScore","negativeScore", "negativeRegularScore", "commercialScore","grade","score","pending",
                          "inIcuCurrently" ,"inIcuCumulative","hospitalizedCurrently","onVentilatorCurrently","hospitalizedCumulative",
                          "onVentilatorCumulative","posNeg","hospitalized","fips", "recovered","dateModified","dateChecked","notes","hash","lastUpdateEt","checkTimeEt","total"], axis=1)

#Create a list of the mid west states
mw_state_list = ['IL', 'ND','SD','NE','KS','MO','IA','MN','WI','MI','IN','OH']

# Slice the original dataframe using the list of mid west states
mw_covid_df= covid_df[covid_df['state'].isin(mw_state_list)]

mw_covid_df =mw_covid_df.reset_index()
mw_covid_df["Mortality Rate (per 100)"] = np.round(100*mw_covid_df["death"]/mw_covid_df["positive"],2)
mw_covid_df["Positive Rate (per 100)"] = np.round(100*mw_covid_df["positive"]/mw_covid_df["totalTestResults"],2)
mw_covid_df
# Out:
#     index state  positive  negative   death  totalTestResults  \
# 0      12    IA      1899     16986    49.0             18885
# 1      14    IL     23247     87369   868.0            110616
# 2      15    IN      8527     37490   388.0             46017
# 3      16    KS      1426     12721    69.0             14147
# 4      22    MI     27001     59225  1768.0             86226
# 5      23    MN      1695     37546    79.0             39241
# 6      24    MO      4686     43292   133.0             47978
# 7      28    ND       341     10575     9.0             10916
# 8      29    NE       871     10486    18.0             11357
# 9      35    OH      7153     60721   324.0             67874
# 10     41    SD       988      8308     6.0              9296
# 11     48    WI      3555     37997   170.0             41552
#
#     Mortality Rate (per 100)  Positive Rate (per 100)
# 0                       2.58                    10.06
# 1                       3.73                    21.02
# 2                       4.55                    18.53
# 3                       4.84                    10.08
# 4                       6.55                    31.31
# 5                       4.66                     4.32
# 6                       2.84                     9.77
# 7                       2.64                     3.12
# 8                       2.07                     7.67
# 9                       4.53                    10.54
# 10                      0.61                    10.63
# 11                      4.78                     8.56

# %% [markdown]
# # Total reported cases till date in the Midwest

# %%
#Midwest reported cases
mw_covid_sum_df =mw_covid_df
mw_covid_sum_df.loc['total'] =mw_covid_sum_df.sum(numeric_only=True, axis =0)
total_positive =mw_covid_sum_df["positive"].sum()
total_negative =mw_covid_sum_df["negative"].sum()
total_death =mw_covid_sum_df["death"].sum()
mw_covid_sum_df

total=pd.DataFrame([[total_positive, total_negative,total_death]],columns=['Total MW Positives', 'Total MW Negatives', 'Total MW Deaths'])
total.style.background_gradient(cmap='Wistia',subset=["Total MW Positives"])\
                        .background_gradient(cmap='Reds',subset=["Total MW Deaths"])\
                        .background_gradient(cmap='Blues',subset=["Total MW Negatives"])
# Out:
# <style  type="text/css" >
#     #T_28233b82_8670_11ea_be84_acbc3281cc65row0_col0 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_28233b82_8670_11ea_be84_acbc3281cc65row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_28233b82_8670_11ea_be84_acbc3281cc65row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_28233b82_8670_11ea_be84_acbc3281cc65" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total MW Positives</th>        <th class="col_heading level0 col1" >Total MW Negatives</th>        <th class="col_heading level0 col2" >Total MW Deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28233b82_8670_11ea_be84_acbc3281cc65level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_28233b82_8670_11ea_be84_acbc3281cc65row0_col0" class="data row0 col0" >162778.000000</td>
#                         <td id="T_28233b82_8670_11ea_be84_acbc3281cc65row0_col1" class="data row0 col1" >845432.000000</td>
#                         <td id="T_28233b82_8670_11ea_be84_acbc3281cc65row0_col2" class="data row0 col2" >7762.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Positive cases in Midwest states

# %%
#Plot Positives cases in Midwest
state_and_positive = mw_covid_df[["state","positive"]]
#Drop Nan values
state_and_positive=state_and_positive.dropna()
#Set the index to be "State" so they will be used as labels
state_and_positive = state_and_positive.set_index("state").sort_values('positive')

# Use DataFrame.plot() in order to create a bar chart of the data
state_and_positive.plot(kind="barh", color="red",figsize=(10,3))

# Set a title for the chart
plt.title("Positive Covid cases Per State in Midwest",fontsize=20)
plt.grid(alpha=0.3)
plt.show()
plt.tight_layout()
plt.savefig("fig1.png")

# %% [markdown]
# # Negative cases in Midwest states

# %%
#Plot Negatives cases in Midwest
state_and_negative = mw_covid_df[["state","negative"]]
#Drop Nan values
state_and_negative=state_and_negative.dropna()
#Set the index to be "State" so they will be used as labels
state_and_negative = state_and_negative.set_index("state").sort_values('negative')

# Use DataFrame.plot() in order to create a bar chart of the data
state_and_negative.plot(kind="barh", color="green",figsize=(10,3))

# Set a title for the chart
plt.title("Negative Covid cases Per State in Midwest",fontsize=20)
plt.grid(alpha=0.3)
plt.show()
plt.tight_layout()
plt.savefig("fig2.png")

# %% [markdown]
# # Deaths due to Covid 19 in Midwest states

# %%
#Plot Deaths in Midwest
state_and_death = mw_covid_df[["state","death"]]
#Drop Nan values
state_and_death=state_and_death.dropna()
#Set the index to be "State" so they will be used as labels
state_and_death = state_and_death.set_index("state").sort_values('death')

# Use DataFrame.plot() in order to create a bar chart of the data
state_and_death.plot(kind="barh",color ="black",figsize=(10,3))

# Set a title for the chart
plt.title("Deaths due to Covid cases Per State in Midwest",fontsize=20)
plt.grid(alpha=0.3)
plt.show()
plt.tight_layout()
plt.savefig("fig3.png")

# %% [markdown]
# # Analysis of  Census data for Poverty count

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
#census_pd["Poverty Rate"] = 100 * census_pd["Poverty Count"].astype(int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
#census_pd["Unemployment Rate"] = 100 * \
#    census_pd["Unemployment Count"].astype(int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["State", "Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count"]]
census_pd = census_pd.drop('State', 1)
census_pd.rename({'Name': 'state'}, axis=1, inplace=True)
#Create a list of the mid west states
mw2_state_list = ['Illinois', 'North Dakota','South Dakota','Nebraska','Kansas','Minnesota','Iowa','Missouri','Wisconsin','Michigan',
                  'Indiana','Ohio']

# Slice the original dataframe using the list of mid west states
census_pd= census_pd[census_pd['state'].isin(mw2_state_list)]
census_pd['state']=census_pd['state'].replace({'North Dakota':'ND','South Dakota':'SD','Nebraska':'NE','Kansas':'KS','Missouri':'MO','Iowa':'IA',
                           'Minnesota':'MN','Wisconsin':'WI','Michigan':'MI','Illinois':'IL','Indiana':'IN','Ohio':'OH'})
census_pd2 =census_pd.sort_values('Poverty Count',ascending=False)
census_pd2.style.background_gradient(cmap='Reds',subset=["Population"])\
                        .background_gradient(cmap='Blues',subset=["Median Age"])\
                        .background_gradient(cmap='Greens',subset=["Household Income"])\
                        .background_gradient(cmap='Oranges',subset=["Per Capita Income"])\
                        .background_gradient(cmap='YlOrBr',subset=["Poverty Count"])
# Out:
# <style  type="text/css" >
#     #T_c27bf926_8693_11ea_be84_acbc3281cc65row0_col1 {
#             background-color:  #9c0d14;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row0_col2 {
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row0_col3 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row0_col4 {
#             background-color:  #fdd5ab;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row0_col5 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row1_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row1_col2 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row1_col3 {
#             background-color:  #218944;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row1_col4 {
#             background-color:  #c34002;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row1_col5 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row2_col1 {
#             background-color:  #c9181d;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row2_col3 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row2_col4 {
#             background-color:  #fedfc0;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row2_col5 {
#             background-color:  #892f05;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row3_col1 {
#             background-color:  #fb7151;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row3_col2 {
#             background-color:  #a5cde3;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row3_col3 {
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row3_col4 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row3_col5 {
#             background-color:  #fa9125;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row4_col1 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row4_col2 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row4_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row4_col4 {
#             background-color:  #fee0c1;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row4_col5 {
#             background-color:  #fe9e2d;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row5_col1 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row5_col2 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row5_col3 {
#             background-color:  #97d492;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row5_col4 {
#             background-color:  #fd984b;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row5_col5 {
#             background-color:  #fec24d;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row6_col1 {
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row6_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row6_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row6_col4 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row6_col5 {
#             background-color:  #fed573;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row7_col1 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row7_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row7_col3 {
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row7_col4 {
#             background-color:  #fdb170;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row7_col5 {
#             background-color:  #ffefaa;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row8_col1 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row8_col2 {
#             background-color:  #3484bf;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row8_col3 {
#             background-color:  #a7dba0;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row8_col4 {
#             background-color:  #fdad69;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row8_col5 {
#             background-color:  #fff0ad;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row9_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row9_col2 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row9_col3 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row9_col4 {
#             background-color:  #fdb271;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row9_col5 {
#             background-color:  #fff9c9;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row10_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row10_col2 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row10_col3 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row10_col4 {
#             background-color:  #feddbc;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row10_col5 {
#             background-color:  #fffee0;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row11_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row11_col2 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row11_col3 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row11_col4 {
#             background-color:  #c03f02;
#             color:  #f1f1f1;
#         }    #T_c27bf926_8693_11ea_be84_acbc3281cc65row11_col5 {
#             background-color:  #ffffe5;
#             color:  #0

# %% [markdown]
# # Merge data sets to analyse Covid information and Census data

# %%
# Merge the datasets using the sate columns
census_data = pd.merge(mw_covid_df,census_pd, how="left", on="state")

census_data=census_data.dropna()
census_data =census_data.drop('index', 1)
census_data
# Out:
#    state  positive  negative   death  totalTestResults  \
# 0     IA    1899.0   16986.0    49.0           18885.0
# 1     IL   23247.0   87369.0   868.0          110616.0
# 2     IN    8527.0   37490.0   388.0           46017.0
# 3     KS    1426.0   12721.0    69.0           14147.0
# 4     MI   27001.0   59225.0  1768.0           86226.0
# 5     MN    1695.0   37546.0    79.0           39241.0
# 6     MO    4686.0   43292.0   133.0           47978.0
# 7     ND     341.0   10575.0     9.0           10916.0
# 8     NE     871.0   10486.0    18.0           11357.0
# 9     OH    7153.0   60721.0   324.0           67874.0
# 10    SD     988.0    8308.0     6.0            9296.0
# 11    WI    3555.0   37997.0   170.0           41552.0
#
#     Mortality Rate (per 100)  Positive Rate (per 100)  Population  Median Age  \
# 0                       2.58                    10.06   3062553.0        38.1
# 1                       3.73                    21.02  12848554.0        36.8
# 2                       4.55                    18.53   6514861.0        37.1
# 3                       4.84                    10.08   2868107.0        36.0
# 4                       6.55                    31.31   9886095.0        39.1
# 5                       4.66                     4.32   5347740.0        37.6
# 6                       2.84                     9.77   6007182.0        38.0
# 7                       2.64                     3.12    689781.0        36.4
# 8                       2.07                     7.67   1841625.0        36.3
# 9                       4.53                    10.54  11549590.0        39.0
# 10                      0.61                    10.63    825198.0        36.9
# 11                      4.78                     8.56   5706871.0        38.7
#
#     Household Income  Per Capita Income  Poverty Count
# 0            51843.0            27027.0       367414.0
# 1            56797.0            29666.0      1772333.0
# 2            48248.0            24635.0       969881.0
# 3            51332.0            26929.0       382820.0
# 4            48411.0            25681.0      1625982.0
# 5            59836.0            30913.0       598391.0
# 6            47380.0            25649.0       900929.0
# 7            53741.0            29732.0        79433.0
# 8            51672.0            26899.0       228789.0
# 9            48308.0            26046.0      1773853.0
# 10           49495.0            25740.0       112086.0
# 11           52413.0            27523.0       723730.0

# %% [markdown]
# # Analysis of the Death Rate and Poverty count via Graphs
# Comparing the Death rate vs Poverty count in Midwest, we can look at the correlation and see that it is moderately strong. Mortality rate was higher in most areas of higher poverty

# %%
#Plot Death rate vs poverty count in Midwest

## Convert to floats and store Mortality Rate and Poverty Count as x and y values
y_values = census_data['Mortality Rate (per 100)'].astype('float')
x_values = census_data['Poverty Count'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,marker = "o", facecolor = "cyan", edgecolor="black")

# Plot regression line
plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(3,10),fontsize=15,color="red")

# Label plot
plt.ylabel('Mortality Rate (per 100)')
plt.xlabel('Poverty Count')
plt.title("Mortality Rate vs Poverty count in MidWest",fontsize=15)
# Print r square value
print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")

# Calculate the correlation coefficient between Poverty count and Mortality Rate
print(f"The correlation coefficient between Poverty count and Mortality Rate is {round(st.pearsonr(x_values,y_values)[0],2)}")

# Show plot
plt.show()
plt.savefig("fig4.png")
# Out:
# The line equation is y = 0.0x + 2.45
# R squared: 0.37739653456156547
# P value:0.033559695834120856
# The correlation coefficient between Poverty count and Mortality Rate is 0.61

# %% [markdown]
# # Analysis of the Positive Rate and poverty count via Graphs
# #Comparing the Positive rate vs Poverty count in Midwest, we can look at the correlation and see that it is quite strong.

# %%
#Plot Positive rate vs poverty count in Midwest

## Convert to floats and store Mortality Rate and Poverty Count as x and y values
y_values = census_data['Positive Rate (per 100)'].astype('float')
x_values = census_data['Poverty Count'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,marker = "o", facecolor = "cyan", edgecolor="black")
 

#plt.scatter(x_values, weather_df["Max Temp"], marker = "o", facecolor = "cyan", edgecolor="black")
# Plot regression line
plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(13,80000),fontsize=15,color="red")

# Label plot
plt.ylabel('Positive Rate (per 100)')
plt.xlabel('Poverty Count')
plt.title("Positive Rate vs Poverty count in MidWest",fontsize=15)
# Print r square value
print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")

# Calculate the correlation coefficient between Poverty count and Positive Rate
print(f"The correlation coefficient between Poverty count and Positive Rate is {round(st.pearsonr(x_values,y_values)[0],2)}")


# Show plot
plt.show()
plt.savefig("fig5.png")
# Out:
# The line equation is y = 0.0x + 5.28
# R squared: 0.47422009957530353
# P value:0.013270308499938016
# The correlation coefficient between Poverty count and Positive Rate is 0.69

# %% [markdown]
# # Analysis of the Positive Rate and Household Income via Graphs
# Here we have negative correlation.We can say that in lower income households the positive rate seems higher, but not statistically significant.

# %%
#Plot Positive rate vs poverty count in Midwest

## Convert to floats and store Mortality Rate and Poverty Count as x and y values

x_values = census_data['Household Income'].astype('float')
y_values = census_data['Positive Rate (per 100)'].astype('float')



# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The line equation is {line_eq}")
# Plot scatter plot
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,marker = "o", facecolor = "cyan", edgecolor="black")

# Plot regression line
plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(25,40000),fontsize=11,color="red")

plt.xlim([45000, 60000])
plt.ylim([2,30])
figsize=(6,3)
# Label plot
plt.ylabel('Positive Rate (per 100)')
plt.xlabel('Household Income')
plt.title("Positive Rate vs Household Income in MidWest",fontsize=15)
# Print r square value
print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")

# Calculate the correlation coefficient between Household Income and Positive Rate
print(f"The correlation coefficient between Household Income and Positive Rate is {round(st.pearsonr(x_values,y_values)[0],2)}")

# Show plot
plt.show()
plt.savefig("fig6.png")
# Out:
# The line equation is y = -0.0x + 47.13
# R squared: 0.10428969632696994
# P value:0.30590901758439987
# The correlation coefficient between Household Income and Positive Rate is -0.32

# %% [markdown]
# # Analysis of Spread and Death due to COVID 19 in the Midwest
# The number of deaths in the midwest went up in the first 2 weeks of April but after that the trend has been the same.
# The total number of recovered cases is far less than the positive cases.

# %%
# Read in the csv file for Covid Data and Create dataframe
covid_timeline_df = pd.read_csv('daily (1).csv')
covid_timeline_df=covid_timeline_df.drop([ "pending","hospitalizedCurrently","hospitalizedCumulative","inIcuCurrently",
                                         "inIcuCumulative","onVentilatorCurrently","onVentilatorCumulative","hash",
                                        "hospitalized","total" ,"posNeg","fips","dateChecked"], axis=1)

,""#Create a list of the mid west states
mw_state_list = ['IL', 'ND','SD','NE','KS','MO','IA','MN','WI','MI','IN','OH']

# Slice the original dataframe using the list of mid west states
mw_covid_timeline_df= covid_timeline_df[covid_timeline_df['state'].isin(mw_state_list)]
mw_covid_timeline_df.date =mw_covid_timeline_df.date.astype(str)
mw_covid_timeline_df['date'] =pd.to_datetime(mw_covid_timeline_df['date'])
mw_covid_timeline_df=mw_covid_timeline_df.dropna()
mw_covid_timeline_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#            date state  positive  negative  recovered   death  \
# 14   2020-04-20    IA    3159.0   22661.0     1235.0    79.0
# 24   2020-04-20    MI   32000.0   81798.0     3237.0  2468.0
# 25   2020-04-20    MN    2470.0   44380.0     1202.0   143.0
# 31   2020-04-20    ND     627.0   14120.0      189.0    13.0
# 45   2020-04-20    SD    1685.0   10641.0      709.0     7.0
# ...         ...   ...       ...       ...        ...     ...
# 1375 2020-03-27    ND      65.0    2427.0       15.0     0.0
# 1389 2020-03-27    SD      58.0    2387.0       21.0     1.0
# 1414 2020-03-26    IA     179.0    2578.0       15.0     1.0
# 1445 2020-03-26    SD      46.0    1973.0       16.0     1.0
# 1481 2020-03-25    MN     287.0   11188.0      122.0     1.0
#
#       totalTestResults  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 14             25820.0            4.0                   0.0            1013.0
# 24            113798.0           77.0                   0.0            3561.0
# 25             46850.0            9.0                  28.0            1020.0
# 31             14747.0            3.0                   2.0            1075.0
# 45             12326.0            0.0                  13.0             214.0
# ...                ...            ...                   ...               ...
# 1375            2492.0            0.0                   3.0             388.0
# 1389            2445.0            0.0                   0.0             414.0
# 1414            2757.0            0.0                  10.0               0.0
# 1445            2019.0            0.0                   0.0            1154.0
# 1481           11475.0            0.0                  14.0            5638.0
#
#       positiveIncrease  totalTestResultsIncrease
# 14               257.0                    1270.0
# 24               576.0                    4137.0
# 25               114.0                    1134.0
# 31                42.0                    1117.0
# 45                50.0                     264.0
# ...                ...                       ...
# 1375              13.0                     401.0
# 1389              12.0                     426.0
# 1414              34.0                      34.0
# 1445               5.0                    1159.0
# 1481              25.0                    5663.0
#
# [116 rows x 12 columns]

# %%
df = mw_covid_timeline_df.groupby(['date'])['positive','death'].sum()

ax = df.plot(kind='bar', figsize=(10,6),  fontsize=13,width=0.3);
x_labels = df.index.strftime('%Y-%m-%d')
ax.set_xticklabels(x_labels)
ax.set_alpha(0.8)
ax.set_title("Total Deaths because of COVID-19 in Midwest", fontsize=22)
ax.set_xlabel("Date", fontsize=15);
ax.set_ylabel("Number of Deaths", fontsize=15);
plt.show()
plt.savefig("fig7.png")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df2 = mw_covid_timeline_df.groupby(['date'])['recovered','positive'].sum()

ax = df2.plot(kind='bar', figsize=(10,6),width=0.3);
x_labels = df.index.strftime('%Y-%m-%d')
ax.set_xticklabels(x_labels)
ax.set_alpha(0.8)
ax.set_title("Total Recovered from COVID-19 in Midwest", fontsize=22)
ax.set_xlabel("Date", fontsize=15);

plt.show()
plt.savefig("fig8.png")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Census poverty data from counties in midwest.
#
# Since the sample size at states level is comparatively small, we decided to study the data at county level to get more correct information.

# %%
# Request census data through API
census_county_data = c.acs5.state_county(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), Census.ALL, Census.ALL)
census_county_df = pd.DataFrame(census_county_data)
census_county_df.head()
# Out:
#                                    NAME  B19013_001E  B01003_001E  \
# 0     Las Marías Municipio, Puerto Rico      15779.0       9699.0
# 1         Añasco Municipio, Puerto Rico      16568.0      29086.0
# 2  San Sebastián Municipio, Puerto Rico      14463.0      41798.0
# 3        Bayamón Municipio, Puerto Rico      24374.0     204725.0
# 4         Cataño Municipio, Puerto Rico      18977.0      27669.0
#
#    B01002_001E  B19301_001E  B17001_002E state county
# 0         37.3       7000.0       5563.0    72    083
# 1         39.4       7892.0      14599.0    72    011
# 2         39.7       7174.0      22961.0    72    131
# 3         38.6      12648.0      70734.0    72    021
# 4         35.6      10567.0      13563.0    72    033

# %%
#Clean up the data
census_county_df = census_county_df.drop([ "state","county"],axis=1)
census_county_df.head()
# Out:
#                                    NAME  B19013_001E  B01003_001E  \
# 0     Las Marías Municipio, Puerto Rico      15779.0       9699.0
# 1         Añasco Municipio, Puerto Rico      16568.0      29086.0
# 2  San Sebastián Municipio, Puerto Rico      14463.0      41798.0
# 3        Bayamón Municipio, Puerto Rico      24374.0     204725.0
# 4         Cataño Municipio, Puerto Rico      18977.0      27669.0
#
#    B01002_001E  B19301_001E  B17001_002E
# 0         37.3       7000.0       5563.0
# 1         39.4       7892.0      14599.0
# 2         39.7       7174.0      22961.0
# 3         38.6      12648.0      70734.0
# 4         35.6      10567.0      13563.0

# %%
census_county_df[['county','state']] = census_county_df['NAME'].str.split(", ", expand=True)
census_county_df.head()
# Out:
#                                    NAME  B19013_001E  B01003_001E  \
# 0     Las Marías Municipio, Puerto Rico      15779.0       9699.0
# 1         Añasco Municipio, Puerto Rico      16568.0      29086.0
# 2  San Sebastián Municipio, Puerto Rico      14463.0      41798.0
# 3        Bayamón Municipio, Puerto Rico      24374.0     204725.0
# 4         Cataño Municipio, Puerto Rico      18977.0      27669.0
#
#    B01002_001E  B19301_001E  B17001_002E                   county        state
# 0         37.3       7000.0       5563.0     Las Marías Municipio  Puerto Rico
# 1         39.4       7892.0      14599.0         Añasco Municipio  Puerto Rico
# 2         39.7       7174.0      22961.0  San Sebastián Municipio  Puerto Rico
# 3         38.6      12648.0      70734.0        Bayamón Municipio  Puerto Rico
# 4         35.6      10567.0      13563.0         Cataño Municipio  Puerto Rico

# %%
census_county_df['county'] = census_county_df['county'].str.replace(" County", "")
census_county_df
# Out:
#                                       NAME  B19013_001E  B01003_001E  \
# 0        Las Marías Municipio, Puerto Rico      15779.0       9699.0
# 1            Añasco Municipio, Puerto Rico      16568.0      29086.0
# 2     San Sebastián Municipio, Puerto Rico      14463.0      41798.0
# 3           Bayamón Municipio, Puerto Rico      24374.0     204725.0
# 4            Cataño Municipio, Puerto Rico      18977.0      27669.0
# ...                                    ...          ...          ...
# 3216          Monroe County, West Virginia      41234.0      13512.0
# 3217          Morgan County, West Virginia      36046.0      17502.0
# 3218        Nicholas County, West Virginia      40064.0      26168.0
# 3219            Ohio County, West Virginia      41025.0      44156.0
# 3220       Pendleton County, West Virginia      34175.0       7603.0
#
#       B01002_001E  B19301_001E  B17001_002E                   county  \
# 0            37.3       7000.0       5563.0     Las Marías Municipio
# 1            39.4       7892.0      14599.0         Añasco Municipio
# 2            39.7       7174.0      22961.0  San Sebastián Municipio
# 3            38.6      12648.0      70734.0        Bayamón Municipio
# 4            35.6      10567.0      13563.0         Cataño Municipio
# ...           ...          ...          ...                      ...
# 3216         45.8      20294.0       1824.0                   Monroe
# 3217         45.5      22312.0       2651.0                   Morgan
# 3218         44.1      23209.0       4957.0                 Nicholas
# 3219         43.3      26135.0       6453.0                     Ohio
# 3220         48.3      21253.0       1402.0                Pendleton
#
#               state
# 0       Puerto Rico
# 1       Puerto Rico
# 2       Puerto Rico
# 3       Puerto Rico
# 4       Puerto Rico
# ...             ...
# 3216  West Virginia
# 3217  West Virginia
# 3218  West Virginia
# 3219  West Virginia
# 3220  West Virginia
#
# [3221 rows x 8 columns]

# %%
census_county_df = census_county_df.drop(["NAME"],axis=1)
census_county_df.head()
# Out:
#    B19013_001E  B01003_001E  B01002_001E  B19301_001E  B17001_002E  \
# 0      15779.0       9699.0         37.3       7000.0       5563.0
# 1      16568.0      29086.0         39.4       7892.0      14599.0
# 2      14463.0      41798.0         39.7       7174.0      22961.0
# 3      24374.0     204725.0         38.6      12648.0      70734.0
# 4      18977.0      27669.0         35.6      10567.0      13563.0
#
#                     county        state
# 0     Las Marías Municipio  Puerto Rico
# 1         Añasco Municipio  Puerto Rico
# 2  San Sebastián Municipio  Puerto Rico
# 3        Bayamón Municipio  Puerto Rico
# 4         Cataño Municipio  Puerto Rico

# %%
census_county_df = census_county_df[['state','county','B19013_001E','B01003_001E','B01002_001E','B19301_001E','B17001_002E']]
census_county_df.head()
# Out:
#          state                   county  B19013_001E  B01003_001E  \
# 0  Puerto Rico     Las Marías Municipio      15779.0       9699.0
# 1  Puerto Rico         Añasco Municipio      16568.0      29086.0
# 2  Puerto Rico  San Sebastián Municipio      14463.0      41798.0
# 3  Puerto Rico        Bayamón Municipio      24374.0     204725.0
# 4  Puerto Rico         Cataño Municipio      18977.0      27669.0
#
#    B01002_001E  B19301_001E  B17001_002E
# 0         37.3       7000.0       5563.0
# 1         39.4       7892.0      14599.0
# 2         39.7       7174.0      22961.0
# 3         38.6      12648.0      70734.0
# 4         35.6      10567.0      13563.0

# %%
census_county_df = census_county_df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count"})
census_county_df.head()
# Out:
#          state                   county  Household Income  Population  \
# 0  Puerto Rico     Las Marías Municipio           15779.0      9699.0
# 1  Puerto Rico         Añasco Municipio           16568.0     29086.0
# 2  Puerto Rico  San Sebastián Municipio           14463.0     41798.0
# 3  Puerto Rico        Bayamón Municipio           24374.0    204725.0
# 4  Puerto Rico         Cataño Municipio           18977.0     27669.0
#
#    Median Age  Per Capita Income  Poverty Count
# 0        37.3             7000.0         5563.0
# 1        39.4             7892.0        14599.0
# 2        39.7             7174.0        22961.0
# 3        38.6            12648.0        70734.0
# 4        35.6            10567.0        13563.0

# %% [markdown]
# # COVID-19 Data at County Level

# %%
#Import covid data
covid_county_df = pd.read_csv('us-counties.csv')
covid_county_df.head()
# Out:
#       date     county       state     fips  cases  deaths
# 0  1/21/20  Snohomish  Washington  53061.0      1       0
# 1  1/22/20  Snohomish  Washington  53061.0      1       0
# 2  1/23/20  Snohomish  Washington  53061.0      1       0
# 3  1/24/20       Cook    Illinois  17031.0      1       0
# 4  1/24/20  Snohomish  Washington  53061.0      1       0

# %%
most_recent_covid_df = covid_county_df.loc[covid_county_df["date"]=="4/13/20"]
most_recent_covid_df.head()
# Out:
#           date   county    state    fips  cases  deaths
# 53848  4/13/20  Autauga  Alabama  1001.0     19       1
# 53849  4/13/20  Baldwin  Alabama  1003.0     78       1
# 53850  4/13/20  Barbour  Alabama  1005.0     10       0
# 53851  4/13/20     Bibb  Alabama  1007.0     17       0
# 53852  4/13/20   Blount  Alabama  1009.0     15       0

# %% [markdown]
# From here, we only look at data as of Apr 13 2020.

# %%
most_recent_covid_df = most_recent_covid_df.drop(["date"],axis=1)
most_recent_covid_df.head()
# Out:
#         county    state    fips  cases  deaths
# 53848  Autauga  Alabama  1001.0     19       1
# 53849  Baldwin  Alabama  1003.0     78       1
# 53850  Barbour  Alabama  1005.0     10       0
# 53851     Bibb  Alabama  1007.0     17       0
# 53852   Blount  Alabama  1009.0     15       0

# %%
#Create a list of the mid west states
mw_state_list = ["Illinois", 'Indiana','Iowa','Kansas','Michigan','Minnesota','Missouri','Nebraska','North Dakota','Ohio','South Dakota','Wisconsin']
mw_state_list
# Out:
# ['Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Michigan',
#  'Minnesota',
#  'Missouri',
#  'Nebraska',
#  'North Dakota',
#  'Ohio',
#  'South Dakota',
#  'Wisconsin']

# %%
# Select midwest states covid data
mw_covid_county_df = most_recent_covid_df[most_recent_covid_df['state'].isin(mw_state_list)]
mw_covid_county_df = mw_covid_county_df[['state','county','fips','cases','deaths']]
mw_covid_county_df.head()
# Out:
#           state   county     fips  cases  deaths
# 54402  Illinois    Adams  17001.0     26       0
# 54403  Illinois     Bond  17005.0      4       0
# 54404  Illinois    Boone  17007.0     13       1
# 54405  Illinois   Bureau  17011.0      6       0
# 54406  Illinois  Calhoun  17013.0      1       0

# %%
# Select midwest states census data
mw_census_county_df= census_county_df[census_county_df['state'].isin(mw_state_list)]
mw_census_county_df.head()
# Out:
#         state   county  Household Income  Population  Median Age  \
# 622  Michigan   Alcona           37189.0     10785.0        55.8
# 623  Michigan    Alger           37586.0      9497.0        48.1
# 624  Michigan  Allegan           52061.0    111742.0        39.6
# 625  Michigan   Alpena           38016.0     29399.0        46.4
# 626  Michigan   Antrim           45362.0     23504.0        48.3
#
#      Per Capita Income  Poverty Count
# 622            22719.0         1612.0
# 623            19717.0         1257.0
# 624            24140.0        14933.0
# 625            21948.0         4999.0
# 626            24370.0         3570.0

# %%
# Merge covid and census data
mw_census_covid_df = mw_covid_county_df.merge(mw_census_county_df, how='inner', left_on=["state","county"], right_on=["state","county"] )
mw_census_covid_df.head()
# Out:
#       state   county     fips  cases  deaths  Household Income  Population  \
# 0  Illinois    Adams  17001.0     26       0           45073.0     67152.0
# 1  Illinois     Bond  17005.0      4       0           48163.0     17665.0
# 2  Illinois    Boone  17007.0     13       1           60893.0     54068.0
# 3  Illinois   Bureau  17011.0      6       0           48977.0     34594.0
# 4  Illinois  Calhoun  17013.0      1       0           50436.0      5062.0
#
#    Median Age  Per Capita Income  Poverty Count
# 0        40.6            24217.0         9374.0
# 1        40.0            23195.0         2462.0
# 2        37.3            25888.0         6055.0
# 3        43.0            26705.0         3955.0
# 4        45.1            26924.0          593.0

# %%
# Calculate poverty rate, positive covid rate, mortality rate for each county in midwest. 
mw_census_covid_df["Poverty Rate"] = mw_census_covid_df["Poverty Count"].astype(int)/mw_census_covid_df["Population"].astype(int)
mw_census_covid_df["Positive Rate"] = mw_census_covid_df["cases"].astype(int)/mw_census_covid_df["Population"].astype(int)
mw_census_covid_df["Mortality Rate"] = mw_census_covid_df["deaths"].astype(int)/mw_census_covid_df["cases"].astype(int)

mw_census_covid_df.head()
# Out:
#       state   county     fips  cases  deaths  Household Income  Population  \
# 0  Illinois    Adams  17001.0     26       0           45073.0     67152.0
# 1  Illinois     Bond  17005.0      4       0           48163.0     17665.0
# 2  Illinois    Boone  17007.0     13       1           60893.0     54068.0
# 3  Illinois   Bureau  17011.0      6       0           48977.0     34594.0
# 4  Illinois  Calhoun  17013.0      1       0           50436.0      5062.0
#
#    Median Age  Per Capita Income  Poverty Count  Poverty Rate  Positive Rate  \
# 0        40.6            24217.0         9374.0      0.139594       0.000387
# 1        40.0            23195.0         2462.0      0.139372       0.000226
# 2        37.3            25888.0         6055.0      0.111989       0.000240
# 3        43.0            26705.0         3955.0      0.114326       0.000173
# 4        45.1            26924.0          593.0      0.117147       0.000198
#
#    Mortality Rate
# 0        0.000000
# 1        0.000000
# 2        0.076923
# 3        0.000000
# 4        0.000000

# %% [markdown]
# # Graph average poverty rate

# %%
# Calculate the average poverty rate by state
mw_state_poverty_df = mw_census_covid_df.groupby('state')  
mw_state_poverty_df = pd.DataFrame(mw_state_poverty_df['Poverty Rate'].mean().sort_values())
mw_state_poverty_df
# Out:
#               Poverty Rate
# state
# Nebraska          0.111387
# Iowa              0.111926
# Minnesota         0.113557
# Wisconsin         0.122486
# North Dakota      0.125061
# Illinois          0.129577
# Kansas            0.132744
# Indiana           0.136391
# South Dakota      0.136659
# Ohio              0.148215
# Michigan          0.164307
# Missouri          0.167134

# %%
# Bar plot to show average poverty rate per state
state_poverty_bar_chart = mw_state_poverty_df.plot(kind='barh', figsize=(12,4))
state_poverty_bar_chart.set_title("Average poverty rate per state", fontsize=20)
state_poverty_bar_chart.set_xlabel("Midwest States")
state_poverty_bar_chart.set_ylabel("Average Poverty Rate")

plt.savefig('Average poverty rate per state in midwest.png')
plt.show()

# %% [markdown]
# Missouri, Michigan and Ohio are the highest average poverty rate.

# %% [markdown]
# # Poverty rate distribution in midwest

# %%
# Box plot to show the distribution of poverty rate in each state
mw_county_poverty_dist = mw_census_covid_df.boxplot(column=['Poverty Rate'], by='state',grid=False, rot=45, fontsize=10, figsize=(8,6))
plt.title("Poverty rate distribution in midwest states", y=1.1, fontsize=20 )
plt.xlabel("Midwest States")
plt.ylabel("Poverty rate")

plt.savefig('Poverty rate distribution in midwest states.png')
plt.show()

# %% [markdown]
# Missouri, Michigan and Ohio have the widest distribution of poverty rate in midwest.

# %% [markdown]
# # Graph positive covid cases in midwest

# %%
# Calculate the positive covid case by state
mw_state_covid_df = mw_census_covid_df.groupby('state')  
mw_state_positive_df = pd.DataFrame(mw_state_covid_df['cases'].sum().sort_values())
mw_state_positive_df
# Out:
#               cases
# state
# North Dakota    331
# South Dakota    867
# Nebraska        870
# Kansas         1385
# Minnesota      1616
# Iowa           1710
# Wisconsin      3428
# Missouri       4059
# Ohio           6975
# Indiana        8236
# Illinois      21963
# Michigan      25021

# %%
# Bar plot to show positive covid cases per state
state_positive_bar_chart = mw_state_positive_df.plot(kind='barh', color="red", figsize=(12,4))
state_positive_bar_chart.set_title("Total positive covid cases in midwest states by Apr 13 2020",fontsize=20)
state_positive_bar_chart.set_xlabel("Midwest States")
state_positive_bar_chart.set_ylabel("Total positive covid cases")
plt.savefig('Total positive covid cases in midwest states by Apr 13 2020.png')
plt.show()

# %% [markdown]
# Michigan and Illinois have the most positive covid cases in midwest by Apr 13 2020.

# %% [markdown]
# # Positive covid case distribution in midwest

# %%
# Box plot to show the distribution of positive covid case in each state
mw_county_covid_dist = mw_census_covid_df.boxplot(column=['cases'], by='state',grid=False, rot=45, fontsize=10,figsize=(8,6))
plt.title("Positive covid cases distribution in midwest states by Apr 13 2020", y=1.1, fontsize=20)
plt.xlabel("Midwest States")
plt.ylabel("Positive covid cases")

plt.savefig('Positive covid cases distribution in midwest states by Apr 13 2020.png')
plt.show()

# %% [markdown]
# The median of positive covid cases in midwest sates are similar. However, Michigan and Illinois have more extrame outliers than other states.

# %% [markdown]
# # Bar plot to show total covid death per state

# %%
# Calculate the total covid death by state
mw_state_covid_df = mw_census_covid_df.groupby('state')  
mw_state_mortality_df = pd.DataFrame(mw_state_covid_df['deaths'].sum().sort_values())
mw_state_mortality_df
# Out:
#               deaths
# state
# South Dakota       6
# North Dakota       9
# Nebraska          19
# Iowa              44
# Kansas            63
# Minnesota         70
# Missouri         129
# Wisconsin        155
# Ohio             274
# Indiana          350
# Illinois         800
# Michigan        1591

# %%
# Bar plot to show covid deaths per state
state_mortality_bar_chart = mw_state_mortality_df.plot(kind='barh', color="black", figsize=(12,4))
state_mortality_bar_chart.set_title("Total covid deaths in midwest states by Apr 13 2020",fontsize=20)
state_mortality_bar_chart.set_xlabel("Midwest States")
state_mortality_bar_chart.set_ylabel("Total covid deaths")
plt.savefig('Total covid deaths in midwest states by Apr 13 2020.png')
plt.show()

# %% [markdown]
# Michigan and Illinois have the highest covid death counts in midwest.

# %% [markdown]
# # Covid deaths distribution in midwest

# %%
# Box plot to show the distribution of covid deaths in each state
mw_county_covid_death_dist = mw_census_covid_df.boxplot(column=['deaths'], by='state',grid=False, rot=45, fontsize=10,figsize=(8,6))
plt.title("Covid death distribution in midwest states by Apr 13 2020", y=1.1, fontsize=20)
plt.xlabel("Midwest States")
plt.ylabel("Covid death")

plt.savefig('Covid death distribution in midwest states by Apr 13 2020.png')
plt.show()

# %% [markdown]
# The median of covid death counts in midwest sates are also similar. However, Michigan and Illinois have more extrame outliers than other states.

# %% [markdown]
# # Scatter plot to show the correlation between covid positive rate vs poverty rate in midwest

# %%
# Scatter plot to show poverty rate and positive covid case in midwest counties
x_values = mw_census_covid_df['Poverty Rate']
y_values = mw_census_covid_df['Positive Rate']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,5))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.scatter(x_values,y_values,marker = "o", facecolor = "red", edgecolor="black",alpha=0.75)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.ylim(-0.001,0.01)
plt.title("Poverty rate vs positive covid rate in midwest counties", fontsize=20)
plt.xlabel("Poverty Rate")
plt.ylabel("Positive COVID Rate")
print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")
print(f"The correlation coefficient between Poverty rate and Positive COVID Rate is {round(st.pearsonr(x_values,y_values)[0],2)} in midwest at county level")
plt.savefig('Poverty rate vs positive covid rate in midwest counties.png')

plt.show()
# Out:
# The line equation is y = -0.00053x + 0.00056
# R squared: 0.0013282926070112924
# P value:0.2960466311187357
# The correlation coefficient between Poverty rate and Positive COVID Rate is -0.04 in midwest at county level

# %% [markdown]
# # Scatter plot to show the correlation between covid death rate vs poverty rate in midwest

# %%
# Scatter plot to show poverty rate and covid mortality rate in midwest counties
x_values = mw_census_covid_df['Poverty Rate']
y_values = mw_census_covid_df['Mortality Rate']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,5)) + "x + " + str(round(intercept,5))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.scatter(x_values,y_values,marker = "o", facecolor = "red", edgecolor="black",alpha=0.75)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.title("Poverty rate vs covid mortality rate in midwest counties", fontsize=20)
plt.xlabel("Poverty Rate")
plt.ylabel("COVID Mortality Rate")
print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")
print(f"The correlation coefficient between Poverty rate and COVID Mortality Rate is {round(st.pearsonr(x_values,y_values)[0],2)} in midwest at county level")
plt.savefig('Poverty rate vs covid mortality rate in midwest counties.png')

plt.show()
# Out:
# The line equation is y = 0.09229x + 0.0253
# R squared: 0.0018208017604717617
# P value:0.2211100190375592
# The correlation coefficient between Poverty rate and COVID Mortality Rate is 0.04 in midwest at county level

# %% [markdown]
# # Scatter plot to show the correlation between covid positive case vs poverty count in midwest

# %%
# Scatter plot to show poverty count and positive covid case in midwest counties
x_values = mw_census_covid_df['Poverty Count']
y_values = mw_census_covid_df['cases']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.scatter(x_values,y_values,marker = "o", facecolor = "red", edgecolor="black",alpha=0.75)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.title("Poverty count vs positive covid count in midwest counties",fontsize=20)
plt.xlabel("Poverty Count")
plt.ylabel("Positive COVID Count")

print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")
print(f"The correlation coefficient between Poverty Count and Positive COVID Case is {round(st.pearsonr(x_values,y_values)[0],2)} in midwest at county level")

plt.savefig('Poverty count vs positive covid count in midwest counties.png')

plt.show()
# Out:
# The line equation is y = 0.017x + -94.838
# R squared: 0.8218215465582823
# P value:3.87569998635685e-310
# The correlation coefficient between Poverty Count and Positive COVID Case is 0.91 in midwest at county level

# %% [markdown]
# # #Scatter plot to show the correlation between covid death count vs poverty count in midwest

# %%
# Scatter plot to show poverty count and covid deaths in midwest counties
x_values = mw_census_covid_df['Poverty Count']
y_values = mw_census_covid_df['deaths']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))
print(f"The line equation is {line_eq}")

# Plot scatter plot
plt.scatter(x_values,y_values,marker = "o", facecolor = "red", edgecolor="black",alpha=0.75)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.title("Poverty count vs covid deaths in midwest counties", fontsize=20)
plt.xlabel("Poverty Count")
plt.ylabel("COVID Deaths")

print(f"R squared: {rvalue**2}")
print(f"P value:{pvalue}")
print(f"The correlation coefficient between Poverty Count and COVID Death is {round(st.pearsonr(x_values,y_values)[0],2)} in midwest at county level")


plt.savefig('Poverty count vs covid deaths in midwest counties.png')

plt.show()
# Out:
# The line equation is y = 0.001x + -3.97
# R squared: 0.6319525333471797
# P value:1.3495801341736383e-180
# The correlation coefficient between Poverty Count and COVID Death is 0.79 in midwest at county level

# %% [markdown]
# # Summary of the analysis:
# 1. At state level, Michigan has the highest positive cases and deaths.
# 2. There is a moderately strong positive correlation between death rate, positive covid rate and poverty.
# 3. Looking at the data overtime, we saw a jump in positive covid case numbers after Apr 3rd 2020, which could be due to the increasing testing.
# 4. For the average poverty rate in midwest states at the county level, Missouri has the highest.
# 5. By checking the distribution of positive covid cases and death in midwest states at county level, we found Michigan and Illinois have the most extreme outliers.
# 6. We found strong positive correlation between posivite covid cases, deaths and poverty count at the county level in midwest, which is consistant with the state level.
